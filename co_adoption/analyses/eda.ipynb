# %% [markdown]
# To pull Fact table into your notebook for EDA, you can use this snippet in a cell:

# %%
import pandas as pd
from google.cloud import bigquery

client = bigquery.Client()

# Replace with your actual project and dataset ID
query = """
    SELECT * FROM `your-project-id.your_dataset_marts.fact_ai_survey`
"""

df = client.query(query).to_dataframe()
df.head()
